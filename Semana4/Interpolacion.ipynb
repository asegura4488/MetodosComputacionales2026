# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionales2026/blob/main/Semana4/Interpolacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %%
X = np.array([1,2,3,4,6])
Y = np.array([0,2.5,4,3,1])

# %%
#X = np.array([1,2])
#Y = np.array([5,6])

# %%
plt.scatter(X,Y,color='r')

# %%
# Programas la base
def Lagrange(x,X,i):

  L = 1 # Productoria
  for j in range(len(X)):
    if i != j:
      L *= (x-X[j])/(X[i]-X[j])
  return L

# %%
# Definir un simbolo
x = sym.Symbol('x',real=True)
x**2
# Out:
# x**2

# %%
L0 = Lagrange(x,X,1).simplify()

# %%
L0
# Out:
# -(x - 6)*(x - 4)*(x - 3)*(x - 1)/8

# %%
def Interpolate(x,X,Y):

  Poly = 0
  for i in range(len(X)):
    Poly += Y[i]*Lagrange(x,X,i)
  return Poly

# %%
p1 = Interpolate(x,X,Y)
p1
# Out:
# 2.5*(3/2 - x/4)*(2 - x/2)*(3 - x)*(x - 1) + 4.0*(2 - x/3)*(4 - x)*(x/2 - 1/2)*(x - 2) + 3.0*(3 - x/2)*(x/3 - 1/3)*(x/2 - 1)*(x - 3) + 1.0*(x/5 - 1/5)*(x/4 - 1/2)*(x/3 - 1)*(x/2 - 2)

# %%
x1 = np.linspace(X[0],X[-1],100)
y1 = Interpolate(x1,X,Y)

# %%
plt.scatter(X,Y,color='r')
plt.plot(x1,y1)
