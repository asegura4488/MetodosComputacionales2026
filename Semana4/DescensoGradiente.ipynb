# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionales2026/blob/main/Semana4/DescensoGradiente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time
import copy

# %%
def Plotter(e):

  fig = plt.figure(figsize=(10,5))
  ax = fig.add_subplot(121)
  ax.set_title('epoch: {:.0f}'.format(e), fontsize=10)

  return fig, ax

# %%
def GradientDescent(epochs=100):

  for e in range(epochs):
    clear_output(wait=True)

    fig, ax = Plotter(e)

    time.sleep(0.5)

    plt.show()

# %%
GradientDescent()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4882/2038151143.py in <cell line: 0>()
# ----> 1 GradientDescent()
#
# /tmp/ipykernel_4882/802268314.py in GradientDescent(epochs)
#       6     fig, ax = Plotter(e)
#       7
# ----> 8     time.sleep(0.5)
#       9
#      10     plt.show()
#
# KeyboardInterrupt:
