# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/MetodosComputacionales2026/blob/main/Semana3/Derivadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 30)

# %%
def f(x):
  return np.sin(x)

# %%
y = f(x)

# %%
plt.plot(x,y)

# %%
def Derivative(f, x, h=1e-2):
  return (f(x+h) - f(x))/h

# %%
Derivative(f,0.)
# Out:
# np.float64(0.9999833334166665)

# %%
Derivative(f,90./180*np.pi)
# Out:
# np.float64(-0.004999958333473664)

# %%
# Queremos pintar
DR = Derivative(f,x)

# %%
plt.plot(x,DR,label='Derecha')
plt.plot(x,np.cos(x),label='Real')
plt.legend()

# %%
plt.plot(x,np.abs(DR-np.cos(x)),label='Real')
